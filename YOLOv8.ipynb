# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 27.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/IndianCurrencyDetection.zip -d/content/
# Out:
# Archive:  /content/drive/MyDrive/IndianCurrencyDetection.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/100__106_jpg.rf.54430923959133a306157a151717737e.jpg
#  extracting: /content/test/images/100__135_jpg.rf.100287046f7d0ecfe49633a79cd9d47f.jpg
#  extracting: /content/test/images/100__139_jpg.rf.67c2e1bd9a841fd5bb9cdf5bb5ead411.jpg
#  extracting: /content/test/images/100__155_jpg.rf.59271b8a86a95f12574d12c647f64700.jpg
#  extracting: /content/test/images/100__170_jpg.rf.b50f9a11fb5081cdad78cf373ec9266a.jpg
#  extracting: /content/test/images/100__177_jpg.rf.f6abbd6298b1bbb306037015c8c821fa.jpg
#  extracting: /content/test/images/100__178_jpg.rf.86792314a7e856ac9481c6a05099d088.jpg
#  extracting: /content/test/images/100__186_jpg.rf.855fd8be20efd71b5423403a10da493c.jpg
# ...

# %%
# !yolo task=detect mode=train epochs=80 data=/content/data.yaml model=yolov8m.pt imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.0.77 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
